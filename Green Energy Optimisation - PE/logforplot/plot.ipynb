# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot
def plotResults(csv1, csv2):
    input1=pd.read_csv(csv1)
    input2=pd.read_csv(csv2)
    x1=input1.as_matrix()
    x2=input2.as_matrix()
    numOfDays = len(input1)
    y=np.arange(1,numOfDays+1,1)

    for ren_iter in range(0,len(input1.keys())):
        pyplot.clf()
        pyplot.plot(y,x1[:,[ren_iter]].reshape(-1),'r',label='Load Dist. based on Predicted Ren. Energy')
        pyplot.plot(y,x2[:,[ren_iter]].reshape(-1),'g',label='Randomised Load Distribution')
        pyplot.xlabel('Days',fontsize=14)
        pyplot.ylabel('Renpercent',fontsize=14)
        pyplot.title('Renpercent for '+input1.keys()[ren_iter],fontsize=17)
        pyplot.legend()
        pyplot.savefig("./fig"+input1.keys()[ren_iter]+".png")
#         pyplot.show()


plotResults('RenPercents.csv', 'RenPercents_nosched.csv')

# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot

# %%
input=pd.read_csv('RenPercents.csv')
input2=pd.read_csv('RenPercents_nosched.csv')
x1=input.as_matrix()
x2=input2.as_matrix()
y=np.arange(1,31,1)

# %%
fig, ax = pyplot.subplots(1)
# x[:,[2]]

# %%
#pyplot.plot(y,x1[1,].as_matrix(),'r',label='DC1')
pyplot.plot(y,x1[:,[0]].reshape(-1),'r',label='Load Dist. based on Predicted Ren. Energy')
pyplot.plot(y,x2[:,[0]].reshape(-1),'g',label='Randomised Load Distribution')
pyplot.xlabel('Days',fontsize=14)
pyplot.ylabel('Renpercent',fontsize=14)
pyplot.title('Renpercent for DC1',fontsize=17)
pyplot.legend()
pyplot.savefig("./figDC1.png")
pyplot.show()

# %%
#pyplot.plot(y,x1[1,].as_matrix(),'r',label='DC1')
pyplot.plot(y,x1[:,[1]].reshape(-1),'r',label='Load Dist. based on Predicted Ren. Energy')
pyplot.plot(y,x2[:,[1]].reshape(-1),'g',label='Randomised Load Distribution')
pyplot.xlabel('Days',fontsize=14)
pyplot.ylabel('Renpercent',fontsize=14)
pyplot.title('Renpercent for DC2',fontsize=17)
pyplot.legend()
pyplot.savefig("./figDC2.png")
pyplot.show()

# %%
#pyplot.plot(y,x1[1,].as_matrix(),'r',label='DC1')
pyplot.plot(y,x1[:,[2]].reshape(-1),'r',label='Load Dist. based on Predicted Ren. Energy')
pyplot.plot(y,x2[:,[2]].reshape(-1),'g',label='Randomised Load Distribution')
pyplot.xlabel('Days',fontsize=14)
pyplot.ylabel('Renpercent',fontsize=14)
pyplot.title('Renpercent for DC3',fontsize=17)
pyplot.legend()
pyplot.savefig("./figDC3.png")
pyplot.show()

# %%
#pyplot.plot(y,x1[1,].as_matrix(),'r',label='DC1')
pyplot.plot(y,x1[:,[3]].reshape(-1),'r',label='Load Dist. based on Predicted Ren. Energy')
pyplot.plot(y,x2[:,[3]].reshape(-1),'g',label='Randomised Load Distribution')
pyplot.xlabel('Days',fontsize=14)
pyplot.ylabel('Renpercent',fontsize=14)
pyplot.title('Renpercent for DC4',fontsize=17)
pyplot.legend()
pyplot.savefig("./figDC4.png")
pyplot.show()

# %%
pyplot.plot(y,x[:,[1]].reshape(-1),'b',label='DC2')
pyplot.plot(y,x[:,[2]].reshape(-1),'g',label='DC3')
pyplot.plot(y,x[:,[3]].reshape(-1),'c',label='DC4')
#pyplot.title('Jobs scheduled on all Datacenters',fontsize=17)
pyplot.xlabel('Renpercet',fontsize=14)
pyplot.ylabel('Days',fontsize=14)
pyplot.legend()
pyplot.show()
